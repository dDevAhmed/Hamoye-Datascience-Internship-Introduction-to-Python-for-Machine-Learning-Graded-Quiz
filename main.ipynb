# %%
import pandas as pd

food_balance = pd.read_csv('FoodBalanceSheetsEAfricaNOFLAG.csv', encoding='latin-1')
food_balance
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_balance.shape
# Out:
# (60943, 12)

# %%
my_tuppy = (1, 2, 5, 8)
my_tuppy[2] = 6
my_tuppy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Ahmed\Documents\IDM\Courses\DATA SCIENCE\Hamoye\Quiz\Quiz_1\main.ipynb Cell 3 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Ahmed/Documents/IDM/Courses/DATA%20SCIENCE/Hamoye/Quiz/Quiz_1/main.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> my_tuppy = (1, 2, 5, 8)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ahmed/Documents/IDM/Courses/DATA%20SCIENCE/Hamoye/Quiz/Quiz_1/main.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> my_tuppy[2] = 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Ahmed/Documents/IDM/Courses/DATA%20SCIENCE/Hamoye/Quiz/Quiz_1/main.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> my_tuppy
#
# TypeError: 'tuple' object does not support item assignment

# %%
food_balance.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
#Area with 7th lowest sum in 2017
food_balance.groupby('Area')[['Y2017', 'Area']].sum().sort_values(ascending=True, by='Y2017')
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
food_balance.iloc[2000]
# Out:
# Area Code                  7
# Area                  Angola
# Item Code               2581
# Item            Ricebran Oil
# Element Code            5131
# Element           Processing
# Unit             1000 tonnes
# Y2014                    0.0
# Y2015                    0.0
# Y2016                    0.0
# Y2017                    0.0
# Y2018                    0.0
# Name: 2000, dtype: object

# %%
food_balance.loc[:, 'Area']
# Out:
# 0         Algeria
# 1         Algeria
# 2         Algeria
# 3         Algeria
# 4         Algeria
#            ...
# 60938    Zimbabwe
# 60939    Zimbabwe
# 60940    Zimbabwe
# 60941    Zimbabwe
# 60942    Zimbabwe
# Name: Area, Length: 60943, dtype: object

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
food_balance.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
food_balance.groupby('Element')[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
food_balance.groupby('Item')[['Y2015', 'Y2018']].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
food_balance.groupby('Area')[['Y2017', 'Area']].sum().sort_values(ascending=False, by='Y2017')
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x1 = y[1][1]
x2 = y[1][1]

print(x1)
print(x2)
# Out:
# 8
# 8

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30, 'Brazil', 92]]
col = ['Age', 'Nationality', 'Overall']

lst_df = pd.DataFrame(lst, columns=col, index=[i for i in range(1,4)])
lst_df
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
_2014_null_values = food_balance['Y2014'].isnull().sum()
total_null_values = food_balance.isnull().sum().sum()

print('Missing data in 2014: ', _2014_null_values)
print('Percentage of missing data in 2014: ', (_2014_null_values / total_null_values) * 100)
# Out:
# Missing data in 2014:  1589
# Percentage of missing data in 2014:  20.86945101129498

# %%
food_balance.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %%
# how to get the total protein supply in Madagascar in 2015
food_balance[food_balance['Area'] == 'Madagascar'].groupby(['Element'])[['Y2015']].sum()
# Out:
#                                            Y2015
# Element
# Domestic supply quantity                31214.98
# Export Quantity                           494.75
# Fat supply quantity (g/capita/day)         91.85
# Feed                                     2070.22
# Food                                    21120.65
# Food supply (kcal/capita/day)            7685.00
# Food supply quantity (kg/capita/yr)       871.59
# Import Quantity                          1721.80
# Losses                                   2176.00
# Other uses (non-food)                    3957.12
# Processing                               1803.00
# Production                              29482.89
# Protein supply quantity (g/capita/day)    173.05
# Residuals                                -616.00
# Seed                                      699.00
# Stock Variation                          -505.00
# Total Population - Both sexes           24234.00

# %%
import numpy as np

array = (
    [
        [94, 89, 63],
        [93, 92, 48],
        [92, 94, 56]
    ]
)

np_array = np.array(array)

np_array[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
food_balance.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...
